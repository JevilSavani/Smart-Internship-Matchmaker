# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
final=pd.DataFrame()
for a in range(1,199):
    url='https://internshala.com/internships/page-{}/'.format(a)
    webpage=requests.get(url).text
    soup=BeautifulSoup(webpage,'lxml')
    company=soup.find_all('div',class_="internship_meta duration_meta")
    name=[]
    stipend=[]
    location=[]
    hiring=[]
    all_skills = [] 
    for i in company:
        name.append(i.find("p").text.strip())
        stipend.append(i.find("span",class_="stipend").text.removesuffix("/month"))
        location.append(i.find("span").text)
        badge = i.find("div", class_="actively-hiring-badge")
        hiring.append(badge.text if badge else "Not actively hiring")

        company_skills = []
        skill_divs = i.find_all("div", class_="job_skill")
        for div in skill_divs:
            company_skills.append(div.text.strip())
        all_skills.append(company_skills)
    df = pd.DataFrame({
    'Name':name,'location':location,'stipend':stipend,"company_id": range(len(all_skills)),
    "skills": all_skills,"hiring":hiring
    })
    final = pd.concat([final, df], ignore_index=True)

# %%
final
# Out:
#                          Name          location              stipend  \
# 0                   Unacademy      \nBangalore    ₹ 15,000 - 20,000
# 1               Export Genius  \nDelhi, Rohini    ₹ 10,000 - 12,000
# 2     ConnectingDots Infotech           \nPune    ₹ 15,000 - 25,000
# 3                      UpGrad     \nDera Bassi             ₹ 11,000
# 4        Visomni Technologies         \nRaipur    ₹ 10,000 - 17,500
# ...                       ...               ...                  ...
# 7614             Connect Karo         \nRemote     ₹ 5,000 - 10,000
# 7615                 Mckinsey      \nBangalore   Competitive stipend
# 7616                 Mckinsey      \nBangalore   Competitive stipend
# 7617                 Qualcomm      \nBangalore   Competitive stipend
# 7618                 Qualcomm      \nHyderabad   Competitive stipend
#
#       company_id                                             skills  \
# 0              0        [Video Editing, Hindi Proficiency (Spoken)]
# 1              1  [Digital Marketing, Email Marketing, Sales Man...
# 2              2  [Email Marketing, LinkedIn Marketing, English ...
# 3              3                          [Effective Communication]
# 4              4                             [OpenCV, Python, Yolo]
# ...          ...                                                ...
# 7614           4  [Social Media Marketing, Leadership, Event Man...
# 7615           5  [MS-PowerPoint, MS-Excel, Effective Communicat...
# 7616           6  [MS-PowerPoint, MS-Excel, Effective Communicat...
# 7617           7  [Linux, Unix, C Programming, C++ Programming, ...
# 7618           8  [MATLAB, Linux, Unix, Algorithms, C Programmin...
#
#                    hiring
# 0         Actively hiring
# 1         Actively hiring
# 2         Actively hiring
# 3         Actively hiring
# 4         Actively hiring
# ...                   ...
# 7614  Not actively hiring
# 7615  Not actively hiring
# 7616  Not actively hiring
# 7617  Not actively hiring
# 7618  Not actively hiring
#
# [7619 rows x 6 columns]

# %%
file_path ="WebScraping_Data.csv"

# %%
final.to_csv(file_path, index=False, encoding="utf-8")

# %%
df=pd.read_csv("WebScraping_Data.csv")

# %%
df
# Out:
#                          Name          location              stipend  \
# 0                   Unacademy      \nBangalore    ₹ 15,000 - 20,000
# 1               Export Genius  \nDelhi, Rohini    ₹ 10,000 - 12,000
# 2     ConnectingDots Infotech           \nPune    ₹ 15,000 - 25,000
# 3                      UpGrad     \nDera Bassi             ₹ 11,000
# 4        Visomni Technologies         \nRaipur    ₹ 10,000 - 17,500
# ...                       ...               ...                  ...
# 7614             Connect Karo         \nRemote     ₹ 5,000 - 10,000
# 7615                 Mckinsey      \nBangalore   Competitive stipend
# 7616                 Mckinsey      \nBangalore   Competitive stipend
# 7617                 Qualcomm      \nBangalore   Competitive stipend
# 7618                 Qualcomm      \nHyderabad   Competitive stipend
#
#       company_id                                             skills  \
# 0              0    ['Video Editing', 'Hindi Proficiency (Spoken)']
# 1              1  ['Digital Marketing', 'Email Marketing', 'Sale...
# 2              2  ['Email Marketing', 'LinkedIn Marketing', 'Eng...
# 3              3                        ['Effective Communication']
# 4              4                       ['OpenCV', 'Python', 'Yolo']
# ...          ...                                                ...
# 7614           4  ['Social Media Marketing', 'Leadership', 'Even...
# 7615           5  ['MS-PowerPoint', 'MS-Excel', 'Effective Commu...
# 7616           6  ['MS-PowerPoint', 'MS-Excel', 'Effective Commu...
# 7617           7  ['Linux', 'Unix', 'C Programming', 'C++ Progra...
# 7618           8  ['MATLAB', 'Linux', 'Unix', 'Algorithms', 'C P...
#
#                    hiring
# 0         Actively hiring
# 1         Actively hiring
# 2         Actively hiring
# 3         Actively hiring
# 4         Actively hiring
# ...                   ...
# 7614  Not actively hiring
# 7615  Not actively hiring
# 7616  Not actively hiring
# 7617  Not actively hiring
# 7618  Not actively hiring
#
# [7619 rows x 6 columns]
