# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
final=pd.DataFrame()
for a in range(1,199):
    url='https://internshala.com/internships/page-{}/'.format(a)
    webpage=requests.get(url).text
    soup=BeautifulSoup(webpage,'lxml')
    company=soup.find_all('div',class_="internship_meta duration_meta")
    name=[]
    stipend=[]
    location=[]
    hiring=[]
    all_skills = [] 
    for i in company:
        name.append(i.find("p").text.strip())
        stipend.append(i.find("span",class_="stipend").text.removesuffix("/month"))
        location.append(i.find("a").text)
        badge = i.find("div", class_="actively-hiring-badge")
        hiring.append(badge.text if badge else "Not actively hiring")

        company_skills = []
        skill_divs = i.find_all("div", class_="job_skill")
        for div in skill_divs:
            company_skills.append(div.text.strip())
        all_skills.append(company_skills)
    df = pd.DataFrame({
    'Name':name,'location':location,'stipend':stipend,"company_id": range(len(all_skills)),
    "skills": all_skills,"hiring":hiring
    })
    final = pd.concat([final, df], ignore_index=True)

# %%
final
# Out:
#                                            Name  \
# 0                               Shades Of India
# 1     Whistlefetch Technologies Private Limited
# 2                                     Klearprop
# 3                                 Export Genius
# 4                                     WAH FILMS
# ...                                         ...
# 7902                               Connect Karo
# 7903                                   Mckinsey
# 7904                                   Mckinsey
# 7905                                   Qualcomm
# 7906                                   Qualcomm
#
#                                    location              stipend  company_id  \
# 0                        Retail Merchandise             ₹ 3,000            0
# 1     Field Marketing Operations And Growth   ₹ 15,000 - 20,000            1
# 2      Real Estate Field Research Executive    ₹ 8,000 - 12,000            2
# 3              Business Development (Sales)   ₹ 10,000 - 12,000            3
# 4                      Video Editing/Making            ₹ 15,000            4
# ...                                     ...                  ...         ...
# 7902    Community Growth & Marketing Intern    ₹ 5,000 - 10,000           12
# 7903                Business Analyst Intern  Competitive stipend          13
# 7904                       Associate Intern  Competitive stipend          14
# 7905             Interim Engineering Intern  Competitive stipend          15
# 7906             Interim Engineering Intern  Competitive stipend          16
#
#                                                  skills               hiring
# 0                                            [MS-Excel]  Not actively hiring
# 1     [Social Media Marketing, Field Work, English P...      Actively hiring
# 2     [Attention to Detail, Time Management, Report ...      Actively hiring
# 3     [Digital Marketing, Email Marketing, Sales Man...      Actively hiring
# 4     [Adobe Photoshop, Video Editing, Adobe Premier...      Actively hiring
# ...                                                 ...                  ...
# 7902  [Social Media Marketing, Leadership, Event Man...  Not actively hiring
# 7903  [MS-PowerPoint, MS-Excel, Effective Communicat...  Not actively hiring
# 7904  [MS-PowerPoint, MS-Excel, Effective Communicat...  Not actively hiring
# 7905  [Linux, Unix, C Programming, C++ Programming, ...  Not actively hiring
# 7906  [MATLAB, Linux, Unix, Algorithms, C Programmin...  Not actively hiring
#
# [7907 rows x 6 columns]

# %%
file_path ="C:\Year 2\Sem 4\SGP\Smart-Internship-Matchmaker\Data\WebScraping_Data.csv"

# %%
final.to_csv(file_path, index=False, encoding="utf-8")

# %%
df=pd.read_csv("C:\Year 2\Sem 4\SGP\Smart-Internship-Matchmaker\Data\WebScraping_Data.csv")

# %%
df
# Out:
#                                            Name  \
# 0                               Shades Of India
# 1     Whistlefetch Technologies Private Limited
# 2                                     Klearprop
# 3                                 Export Genius
# 4                                     WAH FILMS
# ...                                         ...
# 7902                               Connect Karo
# 7903                                   Mckinsey
# 7904                                   Mckinsey
# 7905                                   Qualcomm
# 7906                                   Qualcomm
#
#                                    location              stipend  company_id  \
# 0                        Retail Merchandise             ₹ 3,000            0
# 1     Field Marketing Operations And Growth   ₹ 15,000 - 20,000            1
# 2      Real Estate Field Research Executive    ₹ 8,000 - 12,000            2
# 3              Business Development (Sales)   ₹ 10,000 - 12,000            3
# 4                      Video Editing/Making            ₹ 15,000            4
# ...                                     ...                  ...         ...
# 7902    Community Growth & Marketing Intern    ₹ 5,000 - 10,000           12
# 7903                Business Analyst Intern  Competitive stipend          13
# 7904                       Associate Intern  Competitive stipend          14
# 7905             Interim Engineering Intern  Competitive stipend          15
# 7906             Interim Engineering Intern  Competitive stipend          16
#
#                                                  skills               hiring
# 0                                          ['MS-Excel']  Not actively hiring
# 1     ['Social Media Marketing', 'Field Work', 'Engl...      Actively hiring
# 2     ['Attention to Detail', 'Time Management', 'Re...      Actively hiring
# 3     ['Digital Marketing', 'Email Marketing', 'Sale...      Actively hiring
# 4     ['Adobe Photoshop', 'Video Editing', 'Adobe Pr...      Actively hiring
# ...                                                 ...                  ...
# 7902  ['Social Media Marketing', 'Leadership', 'Even...  Not actively hiring
# 7903  ['MS-PowerPoint', 'MS-Excel', 'Effective Commu...  Not actively hiring
# 7904  ['MS-PowerPoint', 'MS-Excel', 'Effective Commu...  Not actively hiring
# 7905  ['Linux', 'Unix', 'C Programming', 'C++ Progra...  Not actively hiring
# 7906  ['MATLAB', 'Linux', 'Unix', 'Algorithms', 'C P...  Not actively hiring
#
# [7907 rows x 6 columns]
